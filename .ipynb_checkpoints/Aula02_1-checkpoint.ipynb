# %% [markdown]
# # Aula 2 - Aprendizagem Não Supervisionada
# ### Base de dados: Github do Curso e no link ()
#
# ### Exemplo
# - Link: https://github.com/datawaybr/CDKS-0003-FUNDAMENTOS-DE-MACHINE-LEARNING-NAO-SUPERVISIONADO-KICKSTART (referência: https://www.kaggle.com/datasets/jacksondivakarr/phone-classification-dataset/data)
#
# - Descrição: Uma coleção de características que caracterizam telefones celulares, incluindo potência da bateria, especificações da câmera, suporte de rede, memória, dimensões da tela e outros atributos. A coluna 'faixa_de_preço' categoriza os telefones em faixas de preço, tornando este conjunto de dados adequado para tarefas de classificação de telefones celulares e previsão de preço.
#
# - Problema de Negócio: Sua empresa precisa de um sistema inteligente que defina qual será a faixa de preço para uma lista de novos produtos que serão lançados ao longo do ano.
#
# - Objetivo: Imagine que você foi responsável por identificar se há realmente 4 grupos de produtos para serem especificados de modo diferente entre si.

# %%
import pandas as pd
import numpy as np

# %%
# link do git
df = pd.read_csv("bases/phone/dataset1.csv")
#df.drop(columns=['faixa_de_preço'], axis=1, inplace=True)
df
# Out:
#       potência_da_bateria  bluetooth  velocidade_do_processador  dual_sim  \
# 0                     842          0                        2.2         0
# 1                    1021          1                        0.5         1
# 2                     563          1                        0.5         1
# 3                     615          1                        2.5         0
# 4                    1821          1                        1.2         0
# ...                   ...        ...                        ...       ...
# 1995                  794          1                        0.5         1
# 1996                 1965          1                        2.6         1
# 1997                 1911          0                        0.9         1
# 1998                 1512          0                        0.9         0
# 1999                  510          1                        2.0         1
#
#       megapixels_câmera_frontal  4G  memória_interna  profundidade_móvel  \
# 0                             1   0                7                 0.6
# 1                             0   1               53                 0.7
# 2                             2   1               41                 0.9
# 3                             0   0               10                 0.8
# 4                            13   1               44                 0.6
# ...                         ...  ..              ...                 ...
# 1995                          0   1                2                 0.8
# 1996                          0   0               39                 0.2
# 1997                          1   1               36                 0.7
# 1998                          4   1               46                 0.1
# 1999                          5   1               45                 0.9
#
#       peso_do_dispositivo  núcleos_do_processador  ...  altura_do_pixel  \
# 0                     188                       2  ...               20
# 1                     136                       3  ...              905
# 2                     145                       5  ...             1263
# 3                     131                       6  ...             1216
# 4                     141                       2  ...             1208
# ...                   ...                     ...  ...              ...
# 1995                  106                       6  ...             1222
# 1996                  187                       4  ...              915
# 1997                  108                       8  ...              868
# 1998                  145                       5  ...              336
# 1999                  168                       6  ...              483
#
#       largura_do_pixel   RAM  altura_da_tela  largura_da_tela  \
# 0                  756  2549               9                7
# 1                 1988  2631              17                3
# 2                 1716  2603              11                2
# 3                 1786  2769              16                8
# 4                 1212  1411               8                2
# ...                ...   ...             ...              ...
# 1995              1890   668              13                4
# 1996              1965  2032              11               10
# 1997              1632  3057               9                1
# 1998               670   869              18               10
# 1999               754  3919              19                4
#
#       tempo_de_conversação  3G  tela_touch  wi-fi  faixa_de_preço
# 0                       19   0           0      1               1
# 1                        7   1           1      0               2
# 2                        9   1           1      0               2
# 3                       11   1           0      0               2
# 4                       15   1           1      0               1
# ...                    ...  ..         ...    ...             ...
# 1995                    19   1           1      0               0
# 1996                    16   1           1      1               2
# 1997                     5   1           1      0               3
# 1998                    19   1           1      1               0
# 1999                     2   1           1      1               3
#
# [2000 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['potência_da_bateria', 'bluetooth', 'velocidade_do_processador',
#        'dual_sim', 'megapixels_câmera_frontal', '4G', 'memória_interna',
#        'profundidade_móvel', 'peso_do_dispositivo', 'núcleos_do_processador',
#        'megapixels_câmera_principal', 'altura_do_pixel', 'largura_do_pixel',
#        'RAM', 'altura_da_tela', 'largura_da_tela', 'tempo_de_conversação',
#        '3G', 'tela_touch', 'wi-fi', 'faixa_de_preço'],
#       dtype='object')

# %% [markdown]
# ---

# %%
## Qual o valor do K?
## Calma ! Primeiro organizar e entender os dados.

# %%
# !pip install seaborn
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.scatterplot(data = df, x = 'RAM', y = 'potência_da_bateria', hue = 'faixa_de_preço')
# df.drop(columns=['faixa_de_preço'], axis=1, inplace=True)
# Out:
# <Axes: xlabel='RAM', ylabel='potência_da_bateria'>

# %%
sns.scatterplot(data = df, x = 'RAM', y = 'largura_do_pixel', hue = 'faixa_de_preço')
# Out:
# <Axes: xlabel='RAM', ylabel='largura_do_pixel'>

# %%
sns.scatterplot(data = df, x = 'largura_do_pixel', y = 'RAM', hue = 'potência_da_bateria')
# Out:
# <Axes: xlabel='largura_do_pixel', ylabel='RAM'>

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df)
plt.ylabel("Valores")
plt.title('Faixa Dinâmica das Variáveis')
plt.xticks(rotation=90)
plt.show()

# %%
# Calcular a correlação com as demais colunas
df.corrwith(df['faixa_de_preço'])
# Out:
# potência_da_bateria            0.200723
# bluetooth                      0.020573
# velocidade_do_processador     -0.006606
# dual_sim                       0.017444
# megapixels_câmera_frontal      0.021998
# 4G                             0.014772
# memória_interna                0.044435
# profundidade_móvel             0.000853
# peso_do_dispositivo           -0.030302
# núcleos_do_processador         0.004399
# megapixels_câmera_principal    0.033599
# altura_do_pixel                0.148858
# largura_do_pixel               0.165818
# RAM                            0.917046
# altura_da_tela                 0.022986
# largura_da_tela                0.038711
# tempo_de_conversação           0.021859
# 3G                             0.023611
# tela_touch                    -0.030411
# wi-fi                          0.018785
# faixa_de_preço                 1.000000
# dtype: float64

# %%
from pandas.plotting import scatter_matrix
#scatter_matrix(df_copy, diagonal='kde', figsize=(15, 15))
scatter_matrix(df, diagonal='hist', figsize=(15, 15))
plt.suptitle("Matriz de Gráficos de Dispersão", y=0.90, fontsize=16)
plt.show();

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   potência_da_bateria          2000 non-null   int64
#  1   bluetooth                    2000 non-null   int64
#  2   velocidade_do_processador    2000 non-null   float64
#  3   dual_sim                     2000 non-null   int64
#  4   megapixels_câmera_frontal    2000 non-null   int64
#  5   4G                           2000 non-null   int64
#  6   memória_interna              2000 non-null   int64
#  7   profundidade_móvel           2000 non-null   float64
#  8   peso_do_dispositivo          2000 non-null   int64
#  9   núcleos_do_processador       2000 non-null   int64
#  10  megapixels_câmera_principal  2000 non-null   int64
#  11  altura_do_pixel              2000 non-null   int64
#  12  largura_do_pixel             2000 non-null   int64
#  13  RAM                          2000 non-null   int64
#  14  altura_da_tela               2000 non-null   int64
#  15  largura_da_tela              2000 non-null   int64
#  16  tempo_de_conversação         2000 non-null   int64
#  17  3G                           2000 non-null   int64
#  18  tela_touch                   2000 non-null   int64
#  19  wi-fi                        2000 non-null   int64
#  20  faixa_de_preço               2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %% [markdown]
# ----
# ## Preprocessando os dados

# %%
X = df.drop(columns=['faixa_de_preço'], axis=1)
y = df['faixa_de_preço']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %% [markdown]
# ---

# %%
from sklearn import preprocessing

X_train_norm = preprocessing.normalize(X_train)
X_test_norm = preprocessing.normalize(X_test)

# %% [markdown]
# ---

# %% [markdown]
# ## Decidir o K

# %%
# !pip install yellowbrick
# Out:
# Requirement already satisfied: yellowbrick in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.5)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yellowbrick) (3.8.2)
# Requirement already satisfied: scipy>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yellowbrick) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yellowbrick) (1.3.2)
# Requirement already satisfied: numpy>=1.16.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yellowbrick) (1.26.2)
# Requirement already satisfied: cycler>=0.10.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yellowbrick) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (23.0)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn>=1.0.0->yellowbrick) (3.2.0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.16.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
import warnings 
warnings.filterwarnings('ignore')

model = KMeans()
visualizer = KElbowVisualizer(model, k=(2,12))

visualizer.fit(X_train_norm)        
visualizer.show()

# %% [markdown]
# ----

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=5, n_init="auto")
kmeans.fit(X_train_norm)

# %%
kmeans.predict(X_test_norm)

kmeans.cluster_centers_

# %% [markdown]
# ----
# ## Avaliação

# %%
from yellowbrick.cluster import InterclusterDistance

visualizer = InterclusterDistance(kmeans)

visualizer.fit(X_train_norm)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
from yellowbrick.cluster import SilhouetteVisualizer

visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick')

visualizer.fit(X_train_norm) 
visualizer.show()

# %% [markdown]
# ---

# %%
import math 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# Assuming 'df' is your DataFrame
# Replace 'df' with the actual name of your DataFrame

# Select relevant variables
selected_variables = X.columns

# # Create a new DataFrame with only selected variables
# data_for_clustering = X_train_norm[selected_variables]

# Define a range of k values
k_values = range(2, 10)  # You can adjust this range based on your problem

# Visualize silhouette scores for different values of k
fig, ax = plt.subplots(math.floor(max(k_values) / 2), 2, figsize=(15, 8))

for i, k in enumerate(k_values, 1):
    # Initialize k-means for the current value of k
    kmeans = KMeans(n_clusters=k, init='k-means++', n_init=10, max_iter=100, random_state=42)
    q, mod = divmod(k, 2)
    
    # Create SilhouetteVisualizer
    visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(X_train_norm)  # Fit the model and visualize the silhouette scores
    
    # Print the silhouette score
    silhouette_score = visualizer.silhouette_score_
    print(f'For k={k}, Silhouette Score: {silhouette_score:.4f}')

plt.tight_layout()
plt.show()

# %% [markdown]
# ----

# %%
X['cluster'] = kmeans.fit_predict(X)

# Visualize the clustering (example with a pair plot)
sns.pairplot(X, hue='cluster', palette='viridis')
plt.show()

# %%
for variable in selected_variables:
    print(f"Statistics for variable: {variable}\n")
    cluster_statistics = X.groupby('cluster')[variable].describe()
    print(cluster_statistics)
    print("\n" + "=" * 40 + "\n")
